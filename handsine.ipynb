# %%
from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import cv2  # Install opencv-python
import numpy as np

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("./model_3/keras_Model.h5", compile=False)

# Load the labels
class_names = open("./model_3/labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("<IMAGE_PATH>").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24716/2204877079.py in <module>
#      14
#      15 # Replace this with the path to your image
# ---> 16 image = Image.open("<IMAGE_PATH>").convert("RGB")
#      17
#      18 # resizing the image to be at least 224x224 and then cropping from the center
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\PIL\Image.py in open(fp, mode, formats)
#    2973
#    2974     if filename:
# -> 2975         fp = builtins.open(filename, "rb")
#    2976         exclusive_fp = True
#    2977
#
# OSError: [Errno 22] Invalid argument: '<IMAGE_PATH>'

# %%
# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("./model_4/keras_Model.h5", compile=False)

# Load the labels
class_names = open("./model_4/labels.txt", "r").readlines()

# CAMERA can be 0 or 1 based on default camera of your computer
camera = cv2.VideoCapture(0)

while True:
    # Grab the webcamera's image.
    ret, image = camera.read()

    # Resize the raw image into (224-height,224-width) pixels
    image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)

    # Show the image in a window
    cv2.imshow("Webcam Image", image)

    # Make the image a numpy array and reshape it to the models input shape.
    image = np.asarray(image, dtype=np.float32).reshape(1, 224, 224, 3)

    # Normalize the image array
    image = (image / 127.5) - 1

    # Predicts the model
    prediction = model.predict(image)
    index = np.argmax(prediction)
    class_name = class_names[index]
    confidence_score = prediction[0][index]

    # Print prediction and confidence score
    print("Class:", class_name[2:], end="")
    print("Confidence Score:", str(np.round(confidence_score * 100))[:-2], "%")

    # Listen to the keyboard for presses.
    keyboard_input = cv2.waitKey(1)

    # 27 is the ASCII for the esc key on your keyboard.
    if keyboard_input == 27:
        break

camera.release()
cv2.destroyAllWindows()
# Out:
# Class: left
# Confidence Score: 87 %
# Class: left
# Confidence Score: 59 %
# Class: left
# Confidence Score: 78 %
# Class: left
# Confidence Score: 84 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 84 %
# Class: left
# Confidence Score: 80 %
# Class: left
# Confidence Score: 73 %
# Class: left
# Confidence Score: 82 %
# Class: left
# Confidence Score: 83 %
# Class: left
# Confidence Score: 73 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 75 %
# Class: left
# Confidence Score: 84 %
# Class: left
# Confidence Score: 74 %
# Class: left
# Confidence Score: 77 %
# Class: left
# Confidence Score: 87 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 80 %
# Class: left
# Confidence Score: 66 %
# Class: left
# Confidence Score: 69 %
# Class: left
# Confidence Score: 79 %
# Class: left
# Confidence Score: 74 %
# Class: left
# Confidence Score: 55 %
# Class: left
# Confidence Score: 75 %
# Class: left
# Confidence Score: 81 %
# Class: left
# Confidence Score: 74 %
# Class: left
# Confidence Score: 69 %
# Class: left
# Confidence Score: 85 %
# Class: left
# Confidence Score: 78 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 72 %
# Class: left
# Confidence Score: 66 %
# Class: left
# Confidence Score: 57 %
# Class: left
# Confidence Score: 74 %
# Class: left
# Confidence Score: 80 %
# Class: left
# Confidence Score: 61 %
# Class: left
# Confidence Score: 71 %
# Class: left
# Confidence Score: 74 %
# Class: left
# Confidence Score: 70 %
# Class: left
# Confidence Score: 66 %
# Class: left
# Confidence Score: 65 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 66 %
# Class: left
# Confidence Score: 72 %
# Class: left
# Confidence Score: 78 %
# Class: left
# Confidence Score: 79 %
# Class: left
# Confidence Score: 85 %
# Class: left
# Confidence Score: 66 %
# Class: left
# Confidence Score: 81 %
# Class: left
# Confidence Score: 83 %
# Class: left
# Confidence Score: 78 %
# Class: left
# Confidence Score: 73 %
# Class: left
# Confidence Score: 85 %
# Class: left
# Confidence Score: 82 %
# Class: left
# Confidence Score: 62 %
# Class: left
# Confidence Score: 72 %
# Class: left
# Confidence Score: 75 %
# Class: left
# Confidence Score: 80 %
# Class: left
# Confidence Score: 83 %
# Class: left
# Confidence Score: 75 %
# Class: left
# Confidence Score: 72 %
# Class: left
# Confidence Score: 47 %
# Class: left
# Confidence Score: 44 %
# Class: right
# Confidence Score: 53 %
# Class: rotate
# Confidence Score: 38 %
# Class: rotate
# Confidence Score: 76 %
# Class: rotate
# Confidence Score: 74 %
# Class: right
# Confidence Score: 57 %
# Class: right
# Confidence Score: 71 %
# Class: rotate
# Confidence Score: 63 %
# Class: rotate
# Confidence Score: 51 %
# Class: right
# Confidence Score: 88 %
# Class: right
# Confidence Score: 56 %
# Class: right
# Confidence Score: 91 %
# Class: right
# Confidence Score: 97 %
# Class: right
# Confidence Score: 96 %
# Class: right
# Confidence Score: 96 %
# Class: right
# Confidence Score: 96 %
# Class: right
# Confidence Score: 94 %
# Class: right
# Confidence Score: 97 %
# Class: right
# Confidence Score: 98 %
# Class: right
# Confidence Score: 98 %
# Class: right
# Confidence Score: 98 %
# Class: right
# Confidence Score: 97 %
# Class: right
# Confidence Score: 96 %
# Class: right
# Confidence Score: 98 %
# Class: right
# Confidence Score: 98 %
# Class: right
# Confidence Score: 98 %
# Class: right
# Confidence Score: 97 %
# Class: right
# Confidence Score: 95 %
# Confidence Score: 79 %
# Class: left
# Confidence Score: 77 %
# Class: left
# Confidence Score: 83 %
# Class: left
# Confidence Score: 93 %
# Class: left
# Confidence Score: 90 %
# Class: left
# Confidence Score: 92 %
# Class: left
# Confidence Score: 85 %
# Class: left
# Confidence Score: 75 %
# Class: left
# Confidence Score: 90 %
# Class: left
# Confidence Score: 93 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 84 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 88 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 92 %
# Class: left
# Confidence Score: 81 %
# Class: left
# Confidence Score: 90 %
# Class: left
# Confidence Score: 90 %
# Class: left
# Confidence Score: 90 %
# Class: left
# Confidence Score: 85 %
# Class: left
# Confidence Score: 80 %
# Class: left
# Confidence Score: 92 %
# Class: left
# Confidence Score: 95 %
# Class: left
# Confidence Score: 72 %
# Class: left
# Confidence Score: 88 %
# Class: left
# Confidence Score: 54 %
# Class: left
# Confidence Score: 78 %
# Class: left
# Confidence Score: 84 %
# Class: left
# Confidence Score: 86 %
# Class: left
# Confidence Score: 68 %
# Class: left
# Confidence Score: 79 %
# Class: left
# Confidence Score: 64 %
# Class: left
# Confidence Score: 75 %
# Class: left
# Confidence Score: 78 %
# Class: left
# Confidence Score: 68 %
# Class: left
# Confidence Score: 60 %
# Class: left
# Confidence Score: 60 %
# Class: left
# Confidence Score: 63 %
# Class: left
# Confidence Score: 58 %
# Class: left
# Confidence Score: 71 %
# Class: left
# Confidence Score: 64 %
# Class: left
# Confidence Score: 52 %
# Class: left
# Confidence Score: 64 %
# Class: left
# Confidence Score: 55 %
# Class: left
# Confidence Score: 53 %
# Class: left
# Confidence Score: 61 %
# Class: left
# Confidence Score: 67 %
# Class: left
# Confidence Score: 83 %
# Class: left
# Confidence Score: 75 %
# Class: left
# Confidence Score: 62 %
# Class: left
# Confidence Score: 55 %
# Class: left
# Confidence Score: 58 %
# Class: left
# Confidence Score: 70 %
# Class: left
# Confidence Score: 71 %
# Class: left
# Confidence Score: 64 %
# Class: left
# Confidence Score: 62 %
# Class: left
# Confidence Score: 48 %
# Class: left
# Confidence Score: 67 %
# Class: left
# Confidence Score: 66 %
# Class: left
# Confidence Score: 51 %
# Class: left
# Confidence Score: 64 %
# Class: left
# Confidence Score: 52 %
# Class: left
# Confidence Score: 83 %
# Class: left
# Confidence Score: 74 %
# Class: left
# Confidence Score: 82 %
# Class: left
# Confidence Score: 74 %
# Class: left
# Confidence Score: 66 %
# Class: left
# Confidence Score: 80 %
# Class: left
# Confidence Score: 87 %
# Class: left
# Confidence Score: 81 %
# Class: left
# Confidence Score: 85 %
# Class: left
# Confidence Score: 63 %
# Class: left
# Confidence Score: 80 %
# Class: left
# Confidence Score: 83 %
# Class: left
# Confidence Score: 61 %
# Class: left
# Confidence Score: 85 %
# Class: left
# Confidence Score: 91 %
# Class: left
# Confidence Score: 80 %
# Class: left
# Confidence Score: 79 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 85 %
# Class: left
# Confidence Score: 76 %
# Class: left
# Confidence Score: 81 %
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19336/3580169964.py in <module>
#      28
#      29     # Predicts the model
# ---> 30     prediction = model.predict(image)
#      31     index = np.argmax(prediction)
#      32     class_name = class_names[index]
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1787           for step in data_handler.steps():
#    1788             callbacks.on_predict_batch_begin(step)
# -> 1789             tmp_batch_outputs = self.predict_function(iterator)
#    1790             if data_handler.should_sync:
#    1791               context.async_wait()
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     947       # In this case we have not created variables on the first call. So we can
#     948       # run the first trace but we should fail if variables are created.
# --> 949       results = self._stateful_fn(*args, **kwds)
#     950       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     951         raise ValueError("Creating variables on a non-first call to a function"
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# c:\Users\sklov\AppData\Local\Programs\Python\Python39\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
print("HELLO")
# Out:
# HELLO

# %%
camera.release()
cv2.destroyAllWindows()
